# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd

# Para la Visualizacion 
# -----------------------------------------------------------------------
import math
import seaborn as sns
import matplotlib.pyplot as plt

# Para los modelos
# -----------------------------------------------------------------------
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Importar métricas de evaluación directamente
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Para la codificación de las variables categóricas
# -----------------------------------------------------------------------
from sklearn.preprocessing import OneHotEncoder 
from category_encoders import TargetEncoder  

# Para la codificación de las variables numéricas
# -----------------------------------------------------------------------
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler, RobustScaler

import pickle
import os
import sys 

import warnings
warnings.filterwarnings("ignore")

sys.path.append(os.path.abspath("../../../src"))   
import soporte_preprocesamiento as b

pd.set_option("display.max_columns", None)

# %%
df_sin_outgrandes= pd.read_pickle("../../../datos/EF/Datos_modelos/grandes_sin_outliers.pkl")

# %% [markdown]
# # **VIVIENDAS GRANDES**

# %%
df_sin_outgrandes.head()
# Out:
#   idq_pv            idq_mun                      tam_muni     factor  \
# 0  Álava  Municipio_pequeño  De 50.000 habitantes o menos  56.857838
# 1  Álava  Municipio_pequeño  De 50.000 habitantes o menos  68.459369
# 2  Álava  Municipio_pequeño  De 50.000 habitantes o menos  98.588608
# 3  Álava  Municipio_pequeño  De 50.000 habitantes o menos  93.993815
# 4  Álava  Municipio_pequeño  De 50.000 habitantes o menos  90.765985
#
#       mesent  anoent yoresi otroresi nresi  \
# 0       Mayo    2021     Si       Si     3
# 1  Diciembre    2021     Si       Si     4
# 2  Diciembre    2021     Si       No     1
# 3  Diciembre    2021     Si       Si     3
# 4  Diciembre    2021     Si       Si     2
#
#                                     regvi                   pagovi  \
# 0    Propia por compra totalmente pagada               Desconocido
# 1    Propia por compra totalmente pagada               Desconocido
# 2    Propia por compra totalmente pagada               Desconocido
# 3    Propia por compra totalmente pagada               Desconocido
# 4  Propia por compra con pagos pendientes  De 700€ a menos de 800€
#
#       calefac          tipocombcale                 tipoagua  wc boducha  \
# 0  individual           Gas natural  abastecimiento público   Si      Si
# 1  individual           Gas natural  abastecimiento público   Si      Si
# 2  individual           Gas natural  abastecimiento público   Si      Si
# 3  individual  Gas butano o propano  abastecimiento público   Si      Si
# 4  individual           Gas natural  abastecimiento público   Si      Si
#
#   aireacond aislam adaptada cocina lavadora lavavajillas secadora horno  \
# 0        No     No       No     Si       Si           Si       No    Si
# 1        No     No       No     Si       Si           Si       No    Si
# 2        No     No       No     Si       Si           Si       Si    Si
# 3        No     No       Si     Si       Si           Si       No    Si
# 4        No     No       No     Si       Si           Si       No    Si
#
#   microondas vitroinduc naseos nsalones ndormito nsototrast notrashabit  \
# 0         Si         Si      2        2        3          1           0
# 1         Si         Si      2        2        4          1           1
# 2         Si         Si      2        1        4          1           0
# 3         Si         Si      4        4        6          2           0
# 4         Si         Si      3        2        3          1           0
#
#              metrosvi nvehiculos papel vidrio envases organico halogena  \
# 0       Más de 180 m2          3    Si     Si      Si       Si       No
# 1  Entre 151 y 180 m2          2    Si     Si      Si       Si       Si
# 2  Entre 151 y 180 m2          2    Si     Si      Si       Si       No
# 3       Más de 180 m2          4    Si     Si      Si       Si       Si
# 4  Entre 151 y 180 m2          4    Si     Si      No       No       Si
#
#   bajoconsumo led                          servdomes  \
# 0          No  Si  No dispone de servicio doméstico
# 1          Si  No  No dispone de servicio doméstico
# 2          Si  Si        servicio doméstico externo
# 3          Si  Si  No dispone de servicio doméstico
# 4          Si  Si  No dispone de servicio doméstico
#
#                                        ayudaext ruidos contamin sucio  \
# 0  No dispone de ayudas externas no remuneradas     No       No    No
# 1  No dispone de ayudas externas no remuneradas     No       No    No
# 2  No dispone de ayudas externas no remuneradas     No       No    Si
# 3  No dispone de ayudas externas no remuneradas     No       No    Si
# 4  No dispone de ayudas externas no remuneradas     No       No    No
#
#   malcomunic pocoverde delincuencia molesturist colegio csalud super farmacia  \
# 0         No        No           No          No      Si     Si    Si       Si
# 1         Si        No           No          No      Si     Si    Si       Si
# 2         Si        No           Si          No      No     Si    No       No
# 3         No        No           No          No      No     No    No       No
# 4         No        No           Si          No      Si     Si    Si       Si
#
#   bares cambioresi segunresi                 lugsegunresi  \
# 0    Si         No        No  No tiene segunda residencia
# 1    Si         No        No  No tiene segunda residencia
# 2    Si         No        No  No tiene segunda residencia
# 3    Si         No        Si                 En otra CCAA
# 4    No         No        Si                 En otra CCAA
#
#                       otraccaa                  otropais  \
# 0  No tiene segunda residencia  No tiene/ está en España
# 1  No tiene segunda residencia  No tiene/ está en España
# 2  No tiene segunda residencia  No tiene/ está en España
# 3                    Cantabria  No tiene/ está en España
# 4         Comunidad Valenciana  No tiene/ está en España
#
#                        diasusa                     ingrehog     tipoedif  \
# 0  No tiene segunda residencia  De 3.000€ a menos de 5.000€  Unifamiliar
# 1  No tiene segunda residencia  De 3.000€ a menos de 5.000€  Unifamiliar
# 2  No tiene segunda residencia  De 1.000€ a menos de 1.500€  Unifamiliar
# 3                60 o más días                 7.500€ o más  Unifamiliar
# 4           Entre 30 y 59 días  De 3.000€ a menos de 5.000€  Unifamiliar
#
#              tipoedifviv  nplantassob nplantasbajo    annoedifinterv  \
# 0  Vivienda unifamiliar             2            0    De 1991 a 2000
# 1  Vivienda unifamiliar             2            0    De 2001 a 2010
# 2  Vivienda unifamiliar             2            1    De 1981 a 1990
# 3  Vivienda unifamiliar             3            0  Anterior a  1900
# 4  Vivienda unifamiliar             2            0    De 2001 a 2010
#
#       estadoedif    accesoedif ascensor garaje       nplazasgar gastuberia  \
# 0          bueno  Es accesible       No     Si                1         Si
# 1  casi perfecto  Es accesible       No     No  No tiene garaje         Si
# 2      muy bueno  Es accesible       No     Si                1         No
# 3       perfecto  Es accesible       No     No  No tiene garaje         No
# 4       perfecto  Es accesible       No     Si                1         Si
#
#   aguacalcent evacuaguares     tipoevacuares nviviendp     vehiculos  \
# 0          Si           Si  Alcantarillado           1  convencional
# 1          No           Si  Alcantarillado           1  convencional
# 2          No           Si         Otro tipo         1  convencional
# 3          Si           Si  Alcantarillado           1  convencional
# 4          Si           Si  Alcantarillado           1  convencional
#
#            renovables      conectividad        ccaa  ayudas_ccaa  \
# 0  no tiene renovable  banda ancha fija  País Vasco         4800
# 1  no tiene renovable  banda ancha fija  País Vasco         4800
# 2  no tiene renovable  banda ancha fija  País Vasco         4800
# 3  no tiene renovable      Sin internet  País Vasco         4800
# 4  no tiene renovable  banda ancha fija  País Vasco         4800
#
#   bonificaciones  horas_de_sol  radiacion_solar  erfotov
# 0            IBI          2147              4.2        0
# 1            IBI          2147              4.2        0
# 2            IBI          2147              4.2        0
# 3            IBI          2147              4.2        0
# 4            IBI          2147              4.2        0

# %% [markdown]
# ### Filtramos las columnas máximas con las que vamos a poder crear un modelo que nos valga teniendo en cuenta los datos de los que disponemos (los de Red Piso)

# %% [markdown]
# Aquí debido a lo que había visto en las correlaciones elimino horas de sol, garaje y tipoedif

# %%
df_sin_outgrandes_fil=df_sin_outgrandes[['idq_pv', 'calefac', 'naseos', 'ndormito', 'metrosvi', 'annoedifinterv', 'estadoedif',
       'accesoedif', 'ascensor', 'nplazasgar', 'aguacalcent', 'ccaa', 'ayudas_ccaa',
       'bonificaciones', 'radiacion_solar', 'erfotov']]

# %%
df_sin_outgrandes_fil.head(2)
# Out:
#   idq_pv     calefac naseos ndormito            metrosvi  annoedifinterv  \
# 0  Álava  individual      2        3       Más de 180 m2  De 1991 a 2000
# 1  Álava  individual      2        4  Entre 151 y 180 m2  De 2001 a 2010
#
#       estadoedif    accesoedif ascensor       nplazasgar aguacalcent  \
# 0          bueno  Es accesible       No                1          Si
# 1  casi perfecto  Es accesible       No  No tiene garaje          No
#
#          ccaa  ayudas_ccaa bonificaciones  radiacion_solar  erfotov
# 0  País Vasco         4800            IBI              4.2        0
# 1  País Vasco         4800            IBI              4.2        0

# %%
columnas_categoricas_gra=df_sin_outgrandes_fil.select_dtypes(include=['object', 'category']).columns

# %%
columnas_categoricas_gra
# Out:
# Index(['idq_pv', 'calefac', 'naseos', 'ndormito', 'metrosvi', 'annoedifinterv',
#        'estadoedif', 'accesoedif', 'ascensor', 'nplazasgar', 'aguacalcent',
#        'ccaa', 'bonificaciones'],
#       dtype='object')

# %% [markdown]
# <!-- **AHORA HACIENDO EL ENCODING Y TRATANDO EL DESBALANCEO** -->

# %%
b.detectar_orden_cat(df_sin_outgrandes_fil, columnas_categoricas_gra,"erfotov")
# Out:
# Estamos evaluando el orden de la variable IDQ_PV
# erfotov                        0   1
# idq_pv
# A Coruña                     421   4
# Albacete                     166   2
# Alicante                     416  14
# Almería                      201   6
# Asturias                     317   3
# Badajoz                      400   3
# Baleares                     729  50
# Barcelona                    893  47
# Burgos                       169   1
# Cantabria                    441   5
# Castellón                    316   6
# Ceuta                         36   0
# Ciudad Real                  341   2
# Cuenca                       226   4
# Cáceres                      211   1
# Cádiz                        275   8
# Córdoba                      254   5
# Girona                       265   8
# Granada                      297   7
# Guadalajara                  273   1
# Guipúzcoa                    119   9
# Huelva                       137   1
# Huesca                       304   3
# Jaén                         284  10
# La Rioja                     361   4
# Las Palmas de Gran Canaria   607  20
# León                         214   1
# Lleida                       220   2
# Lugo                         295   3
# Madrid                      2276  96
# Melilla                       80   0
# Murcia                       478  22
# Málaga                       349   4
# Navarra                      634  12
# Ourense                      203   2
# Palencia                     182   5
# Pontevedra                   378   3
# Salamanca                    124   0
# Santa Cruz de Tenerife       560  30
# Segovia                      210   5
# Sevilla                      497  20
# Soria                        192   5
# Tarragona                    223   8
# Teruel                       287   4
# Toledo                       361   7
# Valencia                     688  17
# Valladolid                   142   2
# Vizcaya                      171   2
# Zamora                       158   2
# Zaragoza                     217   4
# Álava                        105   1
# Ávila                        153   3
# La variable idq_pv SI tiene orden porque su p-valor es : 8.036581563614851e-20
# Estamos evaluando el orden de la variable CALEFAC
# erfotov                                                 0    1
# calefac
# No pero sí aparato que permite calentar alguna ...   2612   59
# No tiene calefacción                                 2307   45
# colectiva                                             985   19
# individual                                          11952  361
# La variable calefac SI tiene orden porque su p-valor es : 0.004567381935774795
# Estamos evaluando el orden de la variable NASEOS
# erfotov     0    1
# naseos
# 1        1630   15
# 2        6855  120
# 3        6658  208
# 4        2067  106
# 5         457   25
# 6         114    3
# 7          32    3
# 8          23    2
# 9           8    1
# 10         12    1
# La variable naseos SI tiene orden porque su p-valor es : 5.61726630831766e-20
# Estamos evaluando el orden de la variable NDORMITO
# erfotov      0    1
# ndormito
# 2          731   17
# 3         6085  167
# 4         7179  215
# 5         2601   51
# 6          862   16
# 7          221   12
# 8           86    2
# 9           57    2
# 10          15    1
# 11           4    0
# 12           7    0
# 13           4    0
# 14           1    0
# 15           3    1
# La variable ndormito SI tiene orden porque su p-valor es : 0.023170694754516063
# Estamos evaluando el orden de la variable METROSVI
# erfotov                 0    1
# metrosvi
# Entre 151 y 180 m2   7478  162
# Más de 180 m2       10378  322
# La variable metrosvi SI tiene orden porque su p-valor es : 0.00025644970045262576
# Estamos evaluando el orden de la variable ANNOEDIFINTERV
# erfotov              0    1
# annoedifinterv
# Anterior a  1900  1666   36
# De 1900 a 1920     823   14
# De 1921 a 1940     743   12
# De 1941 a 1950     545    9
# De 1951 a 1960     709   10
# De 1961 a 1970    1144   19
# De 1971 a 1980    1796   21
# De 1981 a 1990    2233   52
# De 1991 a 2000    3668   95
# De 2001 a 2010    3899  169
# Posterior a 2010   630   47
# La variable annoedifinterv SI tiene orden porque su p-valor es : 2.7225461837511294e-21
# Estamos evaluando el orden de la variable ESTADOEDIF
# erfotov                     0    1
# estadoedif
# bueno                    2498   54
# casi inhabitable            9    0
# casi perfecto            4298  144
# inhabitable                18    0
# levemente mejorable       550    5
# mejorable                  41    0
# moderadamente bueno       918    6
# moderadamente mejorable   119    1
# muy bueno                5323  125
# muy mejorable              17    0
# perfecto                 4065  149
# La variable estadoedif SI tiene orden porque su p-valor es : 3.5952265140477885e-07
# Estamos evaluando el orden de la variable ACCESOEDIF
# erfotov              0    1
# accesoedif
# Es accesible     11555  340
# No es accesible   6301  144
# La variable accesoedif SI tiene orden porque su p-valor es : 0.01355463247018162
# Estamos evaluando el orden de la variable ASCENSOR
# erfotov       0    1
# ascensor
# No        15763  441
# Si         2093   43
# La variable ascensor NO tiene orden porque su p-valor es : 0.06457418150713384
# Estamos evaluando el orden de la variable NPLAZASGAR
# erfotov             0    1
# nplazasgar
# 1                5009  122
# 2                4879  186
# De 101 a 150       87    1
# De 11 a 20        348    3
# De 21 a 50        431    7
# De 3 a 5         1492   46
# De 51 a 100       231    4
# De 6 a 10         272    7
# Más de 150        101    4
# No tiene garaje  5006  104
# La variable nplazasgar SI tiene orden porque su p-valor es : 1.2774643462174538e-05
# Estamos evaluando el orden de la variable AGUACALCENT
# erfotov         0    1
# aguacalcent
# No           9284  200
# Si           8572  284
# La variable aguacalcent SI tiene orden porque su p-valor es : 4.439351052428637e-06
# Estamos evaluando el orden de la variable CCAA
# erfotov                  0   1
# ccaa
# Andalucía             2294  61
# Aragón                 808  11
# Asturias               317   3
# Cantabria              441   5
# Castilla y León       1544  24
# Castilla-La Mancha    1367  16
# Cataluña              1601  65
# Ceuta                   36   0
# Comunidad Valenciana  1420  37
# Extremadura            611   4
# Galicia               1297  12
# Islas Baleares         729  50
# Islas Canarias        1167  50
# La Rioja               361   4
# Madrid                2276  96
# Melilla                 80   0
# Murcia                 478  22
# Navarra                634  12
# País Vasco             395  12
# La variable ccaa SI tiene orden porque su p-valor es : 1.6486521235496853e-23
# Estamos evaluando el orden de la variable BONIFICACIONES
# erfotov             0    1
# bonificaciones
# IBI              7190  162
# IBI y ICIO      10550  322
# Ninguna           116    0
# La variable bonificaciones SI tiene orden porque su p-valor es : 0.0015194384054068475

# %% [markdown]
# #### CONCLUSIONES SOBRE EL ORDEN:
#
# **NO ORDENADAS:**
# - ascensor
#
#  *- get- dummies (pandas)*
#  *- One-Hot Encoding (SKlearn) (es más efectivo)*
#  *Ambas te crean tantas columnas como categorias hay en la columna y hace que en esa solo valga 1 las que coincidan y 0 el resto*
#
#
# **ORDENADAS:**
# - calefac
# - naseos
# - metrosvi
# - tipoedif
# - annoedifinterv
# - idq_pv
# - ndormito
# - estadoedif
# - accesoedif
# - garaje
# - nplazasgar
# - bonificaciones
# - aguacalcent
# - ccaa
#
#
# *- Ordinal Encoding  (Los codifica en función de los pesos que le digamos)*
# *- Label Encoding (Los codifica en orden alfabetico)*
# *- Target Encoding (Los codifica en funcion de las medias (osea en función de la relación con la variable dependiente))*
# *- Frequency Encoding (Los codifica en funcion de la frecuencia(en función del value_counts))*

# %% [markdown]
# OPTO POR UN FREQUENCY

# %%
diccionario_encoding_gra = {"onehot": ["ascensor"], 
                        "dummies": [], # no metemos ninguna
                        'ordinal' : { }, #no metemos ninguna
                        "label": [] , # no metemos ninguna columna porque no queremos en ningún caso que se asignen las categorías de forma aleatoria
                        "frequency": ["calefac", "naseos", "metrosvi", "annoedifinterv","ascensor", "aguacalcent", "ccaa","idq_pv", "ndormito", "estadoedif", "accesoedif", "nplazasgar", "bonificaciones"], 
                        "target": ["calefac", "naseos", "metrosvi", "annoedifinterv", "aguacalcent", "ccaa","idq_pv", "ndormito", "estadoedif", "accesoedif", "nplazasgar", "bonificaciones"]  
                        }

# %%
encoding_gra=b.Encoding(df_sin_outgrandes_fil, diccionario_encoding_gra, "erfotov")
encoded_gra, frecuencia_gra_dicc=encoding_gra.frequency_encoding()

# %%
with open('../../../transformers/preprocesamiento/grandes/frecuencia_gra_dicc.pkl', 'wb') as t:
    pickle.dump(frecuencia_gra_dicc, t)

# %%
encoded_gra.head()
# Out:
#     idq_pv   calefac    naseos  ndormito  metrosvi  annoedifinterv  \
# 0  0.00578  0.671374  0.380316  0.340894  0.583424        0.205180
# 1  0.00578  0.671374  0.380316  0.403162  0.416576        0.221810
# 2  0.00578  0.671374  0.380316  0.403162  0.416576        0.124591
# 3  0.00578  0.671374  0.118484  0.047874  0.583424        0.092803
# 4  0.00578  0.671374  0.374373  0.340894  0.416576        0.221810
#
#    estadoedif  accesoedif  ascensor  nplazasgar  aguacalcent      ccaa  \
# 0    0.139149    0.648582  0.883533    0.279771     0.482879  0.022192
# 1    0.242203    0.648582  0.883533    0.278626     0.517121  0.022192
# 2    0.297056    0.648582  0.883533    0.279771     0.517121  0.022192
# 3    0.229771    0.648582  0.883533    0.278626     0.482879  0.022192
# 4    0.229771    0.648582  0.883533    0.279771     0.482879  0.022192
#
#    ayudas_ccaa  bonificaciones  radiacion_solar  erfotov
# 0         4800        0.400872              4.2        0
# 1         4800        0.400872              4.2        0
# 2         4800        0.400872              4.2        0
# 3         4800        0.400872              4.2        0
# 4         4800        0.400872              4.2        0

# %% [markdown]
# **AHORA HACIENDO LA ESTANDARIZACIÓN**

# %%
scaler_gra=RobustScaler()
nums_gra=encoded_gra.select_dtypes(include=np.number)
nums_gra.drop(columns="erfotov", inplace=True)
nums_gra.drop(columns=columnas_categoricas_gra, inplace=True)
cols_num_gra=nums_gra.columns
dfa_gra=scaler_gra.fit_transform(nums_gra)
df_gra=pd.DataFrame(dfa_gra, columns=cols_num_gra)
encoded_gra[cols_num_gra]= df_gra

# %%
with open('../../../transformers/preprocesamiento/grandes/Robust_scaler.pkl', 'wb') as t:
    pickle.dump(scaler_gra, t)

# %%
encoded_gra.head()
# Out:
#     idq_pv   calefac    naseos  ndormito  metrosvi  annoedifinterv  \
# 0  0.00578  0.671374  0.380316  0.340894  0.583424        0.205180
# 1  0.00578  0.671374  0.380316  0.403162  0.416576        0.221810
# 2  0.00578  0.671374  0.380316  0.403162  0.416576        0.124591
# 3  0.00578  0.671374  0.118484  0.047874  0.583424        0.092803
# 4  0.00578  0.671374  0.374373  0.340894  0.416576        0.221810
#
#    estadoedif  accesoedif  ascensor  nplazasgar  aguacalcent      ccaa  \
# 0    0.139149    0.648582  0.883533    0.279771     0.482879  0.022192
# 1    0.242203    0.648582  0.883533    0.278626     0.517121  0.022192
# 2    0.297056    0.648582  0.883533    0.279771     0.517121  0.022192
# 3    0.229771    0.648582  0.883533    0.278626     0.482879  0.022192
# 4    0.229771    0.648582  0.883533    0.279771     0.482879  0.022192
#
#    ayudas_ccaa  bonificaciones  radiacion_solar  erfotov
# 0     0.533333        0.400872        -2.238095        0
# 1     0.533333        0.400872        -2.238095        0
# 2     0.533333        0.400872        -2.238095        0
# 3     0.533333        0.400872        -2.238095        0
# 4     0.533333        0.400872        -2.238095        0

# %% [markdown]
# AHORA EL DESBALANCEO

# %%
desbalanceo_gra=b.Desbalanceo(encoded_gra,"erfotov")
desbalanceo_gra.visualizar_clase(color="blue", edgecolor="black")

# %% [markdown]
# #### **USO UN TOMEKLINK**

# %% [markdown]
# -  Elimina pares de muestras cercanas entre la clase mayoritaria y la clase minoritaria donde el vecino más cercano de un punto de la clase minoritaria pertenece a la clase mayoritaria.

# %%
encoded_gra.shape
# Out:
# (18340, 16)

# %%
balanced_tomek_gra,tomek_grandes_1=desbalanceo_gra.balancear_clases_tomek()

# %%
with open('../../../transformers/preprocesamiento/grandes/tomek_grandes_1.pkl', 'wb') as t:
    pickle.dump(tomek_grandes_1, t)

# %%
balanced_tomek_gra.shape
# Out:
# (18097, 16)

# %%
balanced_tomek_gra.head(2)
# Out:
#     idq_pv   calefac    naseos  ndormito  metrosvi  annoedifinterv  \
# 0  0.00578  0.671374  0.380316  0.340894  0.583424         0.20518
# 1  0.00578  0.671374  0.380316  0.403162  0.416576         0.22181
#
#    estadoedif  accesoedif  ascensor  nplazasgar  aguacalcent      ccaa  \
# 0    0.139149    0.648582  0.883533    0.279771     0.482879  0.022192
# 1    0.242203    0.648582  0.883533    0.278626     0.517121  0.022192
#
#    ayudas_ccaa  bonificaciones  radiacion_solar  erfotov
# 0     0.533333        0.400872        -2.238095        0
# 1     0.533333        0.400872        -2.238095        0

# %%
round(balanced_tomek_gra["erfotov"].value_counts(normalize=True)*100,2)
# Out:
# erfotov
# 0    97.33
# 1     2.67
# Name: proportion, dtype: float64

# %%
desbalanceo2_gra=b.Desbalanceo(balanced_tomek_gra,"erfotov")
desbalanceo2_gra.visualizar_clase(color="blue", edgecolor="black")

# %% [markdown]
# #### **USO UN SMOTENC PARA QUE NO TOQUE LAS CATEGORICAS**

# %%
columnas_son_cat_encoded_gra=["calefac", "naseos", "metrosvi", "annoedifinterv","ascensor", "aguacalcent", "ccaa","idq_pv", "ndormito", "estadoedif", "accesoedif", "nplazasgar", "bonificaciones"]

# %%
balanced_tomek_gra.shape
# Out:
# (18097, 16)

# %%
df_balanceado_smote_gra, smotenc_grandes=desbalanceo2_gra.balancear_clase_smotenc(columnas_son_cat_encoded_gra, sampling_strategy=0.6)

# %%
with open('../../../transformers/preprocesamiento/grandes/smotenc_grandes.pkl', 'wb') as t:
    pickle.dump(smotenc_grandes, t)

# %%
df_balanceado_smote_gra.head(3)
# Out:
#     idq_pv   calefac    naseos  ndormito  metrosvi  annoedifinterv  \
# 0  0.00578  0.671374  0.380316  0.340894  0.583424        0.205180
# 1  0.00578  0.671374  0.380316  0.403162  0.416576        0.221810
# 2  0.00578  0.671374  0.380316  0.403162  0.416576        0.124591
#
#    estadoedif  accesoedif  ascensor  nplazasgar  aguacalcent      ccaa  \
# 0    0.139149    0.648582  0.883533    0.279771     0.482879  0.022192
# 1    0.242203    0.648582  0.883533    0.278626     0.517121  0.022192
# 2    0.297056    0.648582  0.883533    0.279771     0.517121  0.022192
#
#    ayudas_ccaa  bonificaciones  radiacion_solar  erfotov
# 0     0.533333        0.400872        -2.238095        0
# 1     0.533333        0.400872        -2.238095        0
# 2     0.533333        0.400872        -2.238095        0

# %%
round(df_balanceado_smote_gra["erfotov"].value_counts(normalize=True)*100,2)
# Out:
# erfotov
# 0    62.5
# 1    37.5
# Name: proportion, dtype: float64

# %%
desbalanceo3_gra=b.Desbalanceo(df_balanceado_smote_gra,"erfotov")
desbalanceo3_gra.visualizar_clase(color="blue", edgecolor="black")

# %%
df_balanceado_smote_gra["erfotov"].unique()
# Out:
# array([0, 1])

# %%
df_balanceado_smote_gra.shape
# Out:
# (28180, 16)

# %%
balanced_tomek2_gra,tomek_grandes_2=desbalanceo3_gra.balancear_clases_tomek()

# %%
with open('../../../transformers/preprocesamiento/grandes/tomek_grandes_2.pkl', 'wb') as t:
    pickle.dump(tomek_grandes_2, t)

# %%
balanced_tomek2_gra.shape
# Out:
# (28032, 16)

# %%
round(balanced_tomek2_gra["erfotov"].value_counts(normalize=True)*100,2)
# Out:
# erfotov
# 0    62.3
# 1    37.7
# Name: proportion, dtype: float64

# %%
desbalanceo4_gra=b.Desbalanceo(balanced_tomek2_gra,"erfotov")
desbalanceo4_gra.visualizar_clase(color="blue", edgecolor="black")

# %% [markdown]
# Uso el primer Tomek para reducir un poco la mayoritaria (No demasiado he de decir) y hacer los "márgenes más claros entre las clases. Luego uso el Smotenc que me hace un upsampling y finalmente uso un tomek de nuevo para volver a marcar bien las clases tras haber generado datos con el smotenc.

# %% [markdown]
# **OBSERVAMOS SI HAY ALTAS CORRELACIONES POR SI LAS TENEMOS QUE TRATAR**

# %%
abcc=b.Visualizador(balanced_tomek2_gra)
abcc.correlacion()

# %% [markdown]
# Tratamos las altas correlaciones:
# - Elimino garaje, horas de sol y tipoedif

# %% [markdown]
# ### **Me guardo ya el conjunto de datos preprocesado** (habiendo guardado cada preprocesamiento (transformer) en un pickle)

# %%
balanced_tomek2_gra.to_pickle("../../../datos/EF/Datos_modelos/Modelo_grandes/grandes_preprocesadas.pkl")
